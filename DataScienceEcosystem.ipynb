# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este NoteBook, se presentara un resumen de las Herramientas y Ecosistema de la Ciencia de Datos

# %% [markdown]
# **Objetivos:**
# 1. Conocer librerias de la ciencia de datos.
# 2. Reconocer herramientas populares de la ciencia de datos.
# 3. Evaluar operaciones aritmeticas por medio de Python.

# %% [markdown]
# Dentro de los lenguajes usados en la ciencia de datos, los que mas destacan son los siguientes: Python, R, Julia, SQL

# %% [markdown]
# ### Librerias de Ciencia de Datos
# 1. Numpy
# 2. Pandas
# 3. Seaborn

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | VS Code            |

# %% [markdown]
# ### Examples of Arithmetic Expressions in Python

# %%
#A continuacion, se presenta un ejemplo de aritmetica que incluye suma, multiplicación y división
(3+2*6)/7
# Out:
# 2.142857142857143

# %%
#Esta linea de codigo convertira 200 minutos en horas, al dividirlo en 60
minutos=200
horas=minutos/60
print (horas)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Andrés Felipe Pérez Plazas
